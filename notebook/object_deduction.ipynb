# %%
import pickle

# %%
res = pickle.load(open("results.pkl","rb"))

# %%
result = {}
for itr,r in enumerate(res):
    result[str(itr)]=json.loads(
        r.tojson())
json.dump(result,open("res.json","w+"))

# %%
result
# Out:
# {'0': [{'name': 'person',
#    'class': 0,
#    'confidence': 0.9017637968063354,
#    'box': {'x1': 1408.1302490234375,
#     'y1': 6.70880126953125,
#     'x2': 2360.992431640625,
#     'y2': 899.0033569335938}},
#   {'name': 'person',
#    'class': 0,
#    'confidence': 0.8254185318946838,
#    'box': {'x1': 1.60546875,
#     'y1': 1130.3121337890625,
#     'x2': 1339.0308837890625,
#     'y2': 2140.212890625}},
#   {'name': 'person',
#    'class': 0,
#    'confidence': 0.7692462205886841,
#    'box': {'x1': 1536.419677734375,
#     'y1': 1041.34912109375,
#     'x2': 2995.02978515625,
#     'y2': 2150.004638671875}},
#   {'name': 'book',
#    'class': 73,
#    'confidence': 0.5536291003227234,
#    'box': {'x1': 1348.4351806640625,
#     'y1': 1145.3184814453125,
#     'x2': 1952.140869140625,
#     'y2': 1654.364501953125}}],
#  '1': [{'name': 'person',
#    'class': 0,
#    'confidence': 0.9013084769248962,
#    'box': {'x1': 1408.10400390625,
#     'y1': 6.702392578125,
# ...
